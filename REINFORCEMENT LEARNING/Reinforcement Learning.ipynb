# %% [markdown]
# **Reinforcement Learning**

# %% [markdown]
# It is a type of machine learning method where the AI agent is trained to learn
#
# with time.
#
# AI agent is developed in such a way that it iteratively interacts with the
#
# environment and performs some basic actions.
#
# For every action,feedback is given to the AI Agent
#
# The feedback is in such a form,that the agent gets a positive reward for every
#
# positive action and it gets penalty as a feedback for every negative action
#
# The AI agent aim to perform those actions that lead to getting the maximum
#
# of the rewards(positive feedback)as an output

# %% [markdown]
# In reinforcement learning (RL), the environment is a critical component that interacts with the agent. It represents everything outside the agent that the agent can perceive and act upon. The environment provides the agent with feedback in the form of states and rewards, which the agent uses to learn and improve its policy.

# %% [markdown]
# NOTES:
#
# 1-Learning from interaction with an environment to acheive some long term goal
#
# that is related to the state of the environment
#
# 2-The goal is defined by reward signal,which must be maximized
#
# 3-Agent must be able to partially/fully sense the environment state and take
#
# actions to influence the environment state
#
# 4-Learning depending on the changes occuring in the environment
#
# 5-It is employed by various softwares and machines to find the best possible
#
# behaviour or path it should take in a specific situation
#
# Goal:To acheive the best learning/Result

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Reinforcement Learning differs from supervised learning in a way that in
#
# supervised learning the training data has the answer key with it so the
#
# model is trained with the correct answer itself whereas in reinforcement
#
# learning,there is no answer but the reinforcement agent decides what to do
#
# to perform the given task

# %% [markdown]
# In RL:Learning depending on the chances occuring in the environment

# %% [markdown]
# Eg:Playing a chess board.

# %% [markdown]
# **Goal to win the game:**

# %% [markdown]
# Initially the game does not know what to do or predict.
#
# Only while playing depending on the moves made by the opponent we
#
# make the move either to left,right,forward or backward etc
#
# Similarly in RL,it will learn depending upon the changes happening
#
# in the environment

# %% [markdown]
# RL always depend upon the environmental factors.

# %% [markdown]
# **Goals of RL:**

# %% [markdown]
# To acheive the best result/efficent system.
#
# In the above example playing chess board,ur goal is to win the game.
#
# Making moves against the opponent so that u have the probability of winning
#
# the game

# %% [markdown]
# Main Points in Reinforcemnet Learning:
#
# Input:The input should be an initial state from which the model will start
#
# Output:There are many possible outputs as they are a variety of solutions to a
#
# particular problem
#
# Training:The training is based upon the input,The model will return a state
#
# and the user will decide to reward or punish the model based on its output
#
# The model keeps continues to learn
#
# The best solution is decided based on the maximum reward.

# %% [markdown]
# Types of Reinforcement learning:
#
# Positive:
# Positive Reinforcement is defined as when an event occurs due to a particular
#
# behaviour,increases the strength and the frequency of the behaviour
#
# In other words it has a positive effect on the behaviour

# %% [markdown]
# Advantages:
#
# Maximizes Performance
# Sustain change for a long period of time

# %% [markdown]
# Negative
#
# Negative Reinforcement is defined as strengthening of behaviour because a
#
# negative condition is stopped or avoided.

# %% [markdown]
# Various Practical Applications
#
# RL can be used in robotics for industrial automation(Robotic process automation)
#
# RL can be used in ML and data processing

# %% [markdown]
# RL can be used in large environments in the following situations:
#
# A model of the environment is known,but an analytic solution is not available
#
# Only a simulation model of the environment is given
#
# The only way to collect information about the environment is to interact with
#
# it
