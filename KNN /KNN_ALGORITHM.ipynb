# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
x1 = [7,6,4,3]
x = [5,4,7,8]

target = ['bad','bad','good','good']

feature = list(zip(x1,x))

feature
# Out:
# [(7, 5), (6, 4), (4, 7), (3, 8)]

# %%
model = KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(feature,target)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
model.predict([[3,4]])
# Out:
# array(['good'], dtype='<U4')

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Copy of diabetes (1) (2) (1) (1).csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-0f405c384279> in <cell line: 1>()
# ----> 1 data = pd.read_csv('/content/Copy of diabetes (1) (2) (1) (1).csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
data.head()

# %%
data['Outcome'].unique()

# %%
data.shape

# %%
data.info()

# %%
data.describe()

# %%
corr_matrix = data.corr()['Outcome']

# %%
corr_matrix

# %%
x = data.iloc[:,:8]

y = data.iloc[:,:-1]

x.head()

# %%
y.head()

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20,random_state=0)

# %%
x_train.head()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Importing the dataset

dataset = pd.read_csv('/content/salary_data (2) (1).csv')

# %%
print(dataset.head())

# %%
print(dataset.shape)

# %%
x = dataset.iloc[:, :-1].values #get a copy of dataset exclude last column
y = dataset.iloc[:, 1].values  #get array of dataset in column set
print(x)
print(y)

# %%
#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=1/3, random_state=0)

# %%
plt.plot(X_train)

# %%
plt.plot(y_train)

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()

# %%
X_train = std.fit_transform(X_train)

#std.fit(X_test)

X_test = std.fit_transform(X_test)

# %%
plt.plot(X_train)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X_train)

scaler.transform(X_train)

# %%
from sklearn.preprocessing import StandardScaler
sd = StandardScaler()
sd.fit(x_train)
x_train = sd.transform(x_train)

x_test = sd.fit_transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)

model.fit(X_train,y_train)

# %%
y_pred = model.predict(X_test)

y_pred

# %%
y_test

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test,y_pred)

score

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test,y_pred)

cm

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print("MSC: ",mse)

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average='micro')
print('Precision: %.3f' % precision)

# %%
precision = precision_score(y_test, y_pred,labels=[0,1], average='macro')
print('Precision: %.3f' % precision)

# %%
from sklearn.metrics import recall_score
recall = recall_score(y_test,y_pred,average='micro')
print('Recall: %3f' %recall)

# %%
y_pred1 = model.predict([[6, 148, 72, 35, 0, 33, 0.6, 50]])
y_pred1

# %%
y_pred1 = model.predict([[6,148,72,35,0,33,0.6,50]])
y_pred1

# %%
import pandas as pd

# %%
data = [[1,0,0.002],[2,20,0.0012],[3,30,0.06]]


df = pd.DataFrame(data,columns=["sn","tem","pres"])
df

# %%
x = df.iloc[:,1:2].values

# %%
x

# %%
y = df.iloc[:,2].values

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(x,y)

# %%
y_pred = regressor.predict(x)

# %%
y_pred

# %%
import matplotlib.pyplot as plt

tem = df['tem'].tolist()
pre = df['pres'].tolist()

plt.plot(tem, pre,color='blue')

plt.scatter(tem,y_pred,color='red')

plt.xlabel('temperature')
plt.ylabel('pressure')
#plt.yticks(profitList)

plt.xticks(tem)
plt.title('simple linear regression')
plt.yticks(pre)

plt.legend()
plt.show()

# %%
y = mx+c


#polynomial regression

y-ax+c

y = ax2+bX+c dgree = 2

y = aX^3+bX^2+cx+d

y =

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=3)

x_poly = poly.fit_transform(x)

x_poly

# %% [markdown]
# If degree is 3 the number of feature = 4
#
# then degree is N then the number of feauture is N+1

# %%
lin= LinearRegression()
lin.fit(x_poly,y)

# %%
y_poly = lin.predict(x_poly)

y_poly

# %%
import matplotlib.pyplot as plt

tem = df['tem'].tolist()
pre = df['pres'].tolist()

plt.plot(tem, pre,color='blue')
plt.scatter(tem,y_poly,color='red')

plt.xlabel('temperature')
plt.ylabel('pressure')

plt.xticks(tem)
plt.title('simple linear regression')
plt.yticks(pre)

plt.legend()
plt.show()

# %%
df = pd.DataFrame({'actual value':y,'predicted_value':y_pred,'polynomial value':y_poly})
df

# %%
from sklearn.metrics import r2_score

print('simple linear regression',r2_score(y,y_pred))
print('polynomial regression',r2_score(y,y_poly))

# %%
tem = int(input("enter the temp"))
x_new = poly.fit_transform([[tem]])

# %%
lin.predict(x_new)

# %%
x_new

# %%
lin.predict([[2,4,6,6]])

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/Real estate.csv')

# %%
df.head(2)

# %%
df.shape

# %%
df['No'].unique()

# %%
df.info()

# %%
df.isna().any()

# %%
df = df.drop_duplicates()

# %%
df.shape

# %%
del df['No']
df.head()

# %%
x = df.iloc[:,0:6]
y = df.iloc[:,6]

# %%
x.head(2)

# %%
y.head()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.20,random_state= 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)

# %%
y_pred = regressor.predict(x_test)

# %%
y_train_pred = regressor.predict(x_train)

# %%
y_train_pred

# %%
y_test.head()

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
mse

# %%
training_score = regressor.score(x_train,y_train)
training_score

# %%
testing_score = regressor.score(x_test,y_test)
testing_score

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)

# %%
y_result = regressor.predict([[2012231,5,78,7,5,8]])
print(y_result)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/weatherData (1) (1).csv')

# %%
df.head()
# Out:
#       sunny   hot    high  FALSE   no
# 0     sunny   hot    high   True   no
# 1  overcast   hot    high  False  yes
# 2     rainy  mild    high  False  yes
# 3     rainy  cool  normal  False  yes
# 4     rainy  cool  normal   True   no

# %%
df = pd.read_csv('/content/weatherData (1) (1).csv' ,header= None,names=['Outlook','Temperature','Humidity','windy','play'])

# %%
df.head(10)
# Out:
#     Outlook Temperature Humidity  windy play
# 0     sunny         hot     high  False   no
# 1     sunny         hot     high   True   no
# 2  overcast         hot     high  False  yes
# 3     rainy        mild     high  False  yes
# 4     rainy        cool   normal  False  yes
# 5     rainy        cool   normal   True   no
# 6  overcast        cool   normal   True  yes
# 7     sunny        mild     high  False   no
# 8     sunny        cool   normal  False  yes
# 9     rainy        mild   normal  False  yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Outlook      14 non-null     object
#  1   Temperature  14 non-null     object
#  2   Humidity     14 non-null     object
#  3   windy        14 non-null     bool
#  4   play         14 non-null     object
# dtypes: bool(1), object(4)
# memory usage: 590.0+ bytes

# %%
print(labelfit.inverse_transform([2]))
# Out:
# [2]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Outlook'] = le.fit_transform(df.iloc[:,0])

df.head(10)
# Out:
#    Outlook  Temperature  Humidity  windy  play
# 0        2            1         0      0     0
# 1        2            1         0      1     0
# 2        0            1         0      0     1
# 3        1            2         0      0     1
# 4        1            0         1      0     1
# 5        1            0         1      1     0
# 6        0            0         1      1     1
# 7        2            2         0      0     0
# 8        2            0         1      0     1
# 9        1            2         1      0     1

# %%
df.columns
# Out:
# Index(['Outlook', 'Temperature', 'Humidity', 'windy', 'play'], dtype='object')

# %%
print(labelfit.inverse_transform([2]))
# Out:
# [2]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in df.columns:
  df[i]=le.fit_transform(df[i])

df.head()
# Out:
#    Outlook  Temperature  Humidity  windy  play
# 0        2            1         0      0     0
# 1        2            1         0      1     0
# 2        0            1         0      0     1
# 3        1            2         0      0     1
# 4        1            0         1      0     1

# %%
df['windy'].value_counts()
# Out:
# 0    8
# 1    6
# Name: windy, dtype: int64

# %%
df.head()
# Out:
#    Outlook  Temperature  Humidity  windy  play
# 0        2            1         0      0     0
# 1        2            1         0      1     0
# 2        0            1         0      0     1
# 3        1            2         0      0     1
# 4        1            0         1      0     1

# %%
df.sample(n = 7)
# Out:
#     Outlook  Temperature  Humidity  windy  play
# 5         1            0         1      1     0
# 0         2            1         0      0     0
# 8         2            0         1      0     1
# 13        1            2         0      1     0
# 4         1            0         1      0     1
# 6         0            0         1      1     1
# 10        2            2         1      1     1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

labelfit = le.fit(df['Outlook'])
df['Outlook']=labelfit.transform(df['Outlook'])

df.head()
# Out:
#    Outlook  Temperature  Humidity  windy  play
# 0        2            1         0      0     0
# 1        2            1         0      1     0
# 2        0            1         0      0     1
# 3        1            2         0      0     1
# 4        1            0         1      0     1

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/weatherData (1) (1).csv')

# %%
df.head()
# Out:
#       sunny   hot    high  FALSE   no
# 0     sunny   hot    high   True   no
# 1  overcast   hot    high  False  yes
# 2     rainy  mild    high  False  yes
# 3     rainy  cool  normal  False  yes
# 4     rainy  cool  normal   True   no

# %%
df = pd.read_csv('/content/weatherData (1) (1).csv' ,header= None,names=['Outlook','Temperature','Humidity','windy','play'])

# %%
df.head(10)
# Out:
#     Outlook Temperature Humidity  windy play
# 0     sunny         hot     high  False   no
# 1     sunny         hot     high   True   no
# 2  overcast         hot     high  False  yes
# 3     rainy        mild     high  False  yes
# 4     rainy        cool   normal  False  yes
# 5     rainy        cool   normal   True   no
# 6  overcast        cool   normal   True  yes
# 7     sunny        mild     high  False   no
# 8     sunny        cool   normal  False  yes
# 9     rainy        mild   normal  False  yes

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

labelfit = le.fit(df['Outlook'])
df['Outlook']=labelfit.transform(df['Outlook'])

df.head()
# Out:
#    Outlook Temperature Humidity  windy play
# 0        2         hot     high  False   no
# 1        2         hot     high   True   no
# 2        0         hot     high  False  yes
# 3        1        mild     high  False  yes
# 4        1        cool   normal  False  yes

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()

labelfit1 = le1.fit(df['Temperature'])
df['Temperature']=labelfit1.transform(df['Temperature'])

df.head(10)
# Out:
#    Outlook  Temperature Humidity  windy play
# 0        2            1     high  False   no
# 1        2            1     high   True   no
# 2        0            1     high  False  yes
# 3        1            2     high  False  yes
# 4        1            0   normal  False  yes
# 5        1            0   normal   True   no
# 6        0            0   normal   True  yes
# 7        2            2     high  False   no
# 8        2            0   normal  False  yes
# 9        1            2   normal  False  yes

# %%
from sklearn.preprocessing import LabelEncoder
le2 = LabelEncoder()

labelfit2 = le2.fit(df['Humidity'])
df['Humidity']=labelfit2.transform(df['Humidity'])

df.head(10)
# Out:
#    Outlook  Temperature  Humidity  windy play
# 0        2            1         0  False   no
# 1        2            1         0   True   no
# 2        0            1         0  False  yes
# 3        1            2         0  False  yes
# 4        1            0         1  False  yes
# 5        1            0         1   True   no
# 6        0            0         1   True  yes
# 7        2            2         0  False   no
# 8        2            0         1  False  yes
# 9        1            2         1  False  yes

# %%
from sklearn.preprocessing import LabelEncoder
le3 = LabelEncoder()

labelfit3 = le2.fit(df['windy'])
df['windy']=labelfit3.transform(df['windy'])

df.head(10)
# Out:
#    Outlook  Temperature  Humidity  windy play
# 0        2            1         0      0   no
# 1        2            1         0      1   no
# 2        0            1         0      0  yes
# 3        1            2         0      0  yes
# 4        1            0         1      0  yes
# 5        1            0         1      1   no
# 6        0            0         1      1  yes
# 7        2            2         0      0   no
# 8        2            0         1      0  yes
# 9        1            2         1      0  yes

# %%
from sklearn.preprocessing import LabelEncoder
le4 = LabelEncoder()

labelfit4 = le4.fit(df['play'])
df['play']=labelfit4.transform(df['play'])

df.head(10)
# Out:
#    Outlook  Temperature  Humidity  windy  play
# 0        2            1         0      0     0
# 1        2            1         0      1     0
# 2        0            1         0      0     1
# 3        1            2         0      0     1
# 4        1            0         1      0     1
# 5        1            0         1      1     0
# 6        0            0         1      1     1
# 7        2            2         0      0     0
# 8        2            0         1      0     1
# 9        1            2         1      0     1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

labelfit = le.fit(df['Outlook'])
df['Outlook']=labelfit.transform(df['Outlook'])

df.head()
# Out:
#    Outlook  Temperature  Humidity  windy  play
# 0        2            1         0      0     0
# 1        2            1         0      1     0
# 2        0            1         0      0     1
# 3        1            2         0      0     1
# 4        1            0         1      0     1

# %%
print(labelfit.inverse_transform([2]))
# Out:
# [2]

# %%
print(labelfit1.inverse_transform([0]))
# Out:
# ['cool']

# %%
labelfit.transform([2]).item(0)
# Out:
# 2
